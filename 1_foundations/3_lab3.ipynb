# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contato
# Minas Gerais, Brasil
# (31) 97500-4505 (Mobile)
# renanvinicius.quadros@gmail
# .com
# www.linkedin.com/in/barbosarenan
# (LinkedIn)
# github.com/barbosa-renan
# (Portfolio)
# stackoverflow.com/users/1663657/
# renan-barbosa (Other)
# Principais competências
# Generative AI
# IA generativa
# Preparação de terrenos
# Certifications
# RabbitMQ para Aplicações .NET 1
# Microsoft Certified: Azure
# Fundamentals
# Microsoft Certified: Azure AI
# Fundamentals
# Dominando o ASP.NET MVC Core
# GitHub Actions
# Renan Barbosa
# Consultor Sênior | Tech Architect | AI & Software Engineering | .NET
# | Java | Azure
# Betim, Minas Gerais, Brasil
# Resumo
# Sou Consultor Sênior e Arquiteto de Software na Avanade, com
# mais de 14 anos de experiência em desenvolvimento e arquitetura
# de soluções robustas para diferentes setores, incluindo projetos
# recentes no setor financeiro (FSI). Atuo como Tech Lead na
# liderança de squads multidisciplinares, unindo estratégia, arquitetura
# e execução técnica para entregar projetos de alto impacto.
# Atualmente curso um MBA em Inteligência Artificial Aplicada a
# Negócios, com foco em transformar soluções corporativas por
# meio de machine learning, IA generativa e arquiteturas inteligentes
# em cloud. Tenho aplicado esse conhecimento em projetos que
# envolvem previsão de eventos com dados climáticos e florestais,
# visão computacional para indústria, integração de LLMs em APIs
# corporativas e automação de processos com IA.
# Minha expertise abrange .NET, Java, Python, Azure, AWS,
# arquitetura de microsserviços, mensageria, DevOps e boas práticas
# de engenharia (Clean Code, SOLID, Design Patterns, Testes). Nos
# últimos anos, tenho direcionado minha carreira para unir engenharia
# de software + IA + estratégia de negócios, visando criar soluções
# que sejam ao mesmo tempo tecnicamente escaláveis e orientadas a
# resultados.
# Experiência
# Avanade
# 5 anos 2 meses
# Consultor Sênior | Tech Architect
# junho de 2022 - Present (3 anos 5 meses)
# Nova Lima, Minas Gerais, Brazil
# Consultor Fullstack - Software Engineering
# setembro de 2020 - Present (5 anos 2 meses)
#   Page 1 of 3
# Brazil
# • Referência técnica para um time com 15+ Software Engineers
# • Desenvolvimento de frameworks internos
# • Definição técnica de projetos
# • Melhoria na performance refatorando aplicações com código legado
# HTP Solution
# Engenheiro de software sênior
# maio de 2018 - setembro de 2020 (2 anos 5 meses)
# Belo Horizonte, Minas Gerais
# • Desenvolvimento e manutenção de solução de monitoramento de veículos
# com 4M+ de viagens rastreadas por dia
# • Padronização e evolução de aplicativos mobile com a plataforma Xamarin
# • Referência técnica em aplciações mobile
# Prológica Sistemas
# Desenvolvedor - Sócio
# fevereiro de 2012 - abril de 2020 (8 anos 3 meses)
# Belo Horizonte
# • Identificação de problemas e elaboração de projetos voltados à solução do
# negócio
# • Desenvolvimento de sistemas para desktop e aplicações web
# • Prospecção de clientes e novas oportunidades
# Pumalog
# Assistente de Informática
# abril de 2010 - março de 2011 (1 ano)
# • Desenvolvimento de soluções para geração de boletos bancários
# • Suporte de informática
# Xerox
# Operador de Produção
# dezembro de 2007 - abril de 2010 (2 anos 5 meses)
# • Suporte de Help Desk;
# • Treinamento de usuários;
# • Manutenção preventiva de impressoras;
# • Monitoramento do sistema de impressão -corporativa da Cemig;
# • Editoração e criação de trabalhos gráficos através do Corel Draw e
# Photoshop.
#   Page 2 of 3
# Formação acadêmica
# FIAP
# Master of Business Administration - MBA, AI Business Leadership · (abril de
# 2025 - abril de 2026)
# Pontifícia Universidade Católica de Minas Gerais
# Graduação, Sistemas de Informação · (2011 - 2014)
# Senai Betim
# Técnico, Informática Industrial · (2006 - 2007)
#   Page 3 of 3

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Renan Barbosa"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Renan Barbosa. You are answering questions on Renan Barbosa's website, particularly questions related to Renan Barbosa's career, background, skills and experience. Your responsibility is to represent Renan Barbosa for interactions on the website as faithfully as possible. You are given a summary of Renan Barbosa's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Renan Barbosa. I'm an solutions architect, software engineer and tech lead. I'm originally from Curvelo, Brazil, but I moved to Betim in 1994.\nI love to ride bike and travel with my wife and play with my dogs!\n\n## LinkedIn Profile:\n\xa0 \xa0\nContato\nMinas Gerais, Brasil\n(31) 97500-4505 (Mobile)\nrenanvinicius.quadros@gmail\n.com\nwww.linkedin.com/in/barbosarenan\n(LinkedIn)\ngithub.com/barbosa-renan\n(Portfolio)\nstackoverflow.com/users/1663657/\nrenan-barbosa (Other)\nPrincipais competências\nGenerative AI\nIA generativa\nPreparação de terrenos\nCertifications\nRabbitMQ para Aplicações .NET 1\nMicrosoft Certified: Azure\nFundamentals\nMicrosoft Certified: Azure AI\nFundamentals\nDominando o ASP.NET MVC Core\nGitHub Actions\nRenan Barbosa\nConsultor Sênior | Tech Architect | AI & Software Engineering | .NET\n| Java | Azure\nBetim, Minas Gerais, Brasil\nResumo\nSou Consultor Sênior e Arquiteto de Software na Avanade, com\nmais de 14 anos de experiência em desenvolvimento e arquitetura\nde soluções robustas para diferentes setores, incluindo projetos\nrecentes no setor financeiro (FSI). Atuo como Tech Lead na\nliderança de squads multidisciplinares, unindo estratégia, arquitetura\ne execução técnica para entregar projetos de alto impacto.\nAtualmente curso um MBA em Inteligência Artificial Aplicada a\nNegócios, com foco em transformar soluções corporativas por\nmeio de machine learning, IA generativa e arquiteturas inteligentes\nem cloud. Tenho aplicado esse conhecimento em projetos que\nenvolvem previsão de eventos com dados climáticos e florestais,\nvisão computacional para indústria, integração de LLMs em APIs\ncorporativas e automação de processos com IA.\nMinha expertise abrange .NET, Java, Python, Azure, AWS,\narquitetura de microsserviços, mensageria, DevOps e boas práticas\nde engenharia (Clean Code, SOLID, Design Patterns, Testes). Nos\núltimos anos, tenho direcionado minha carreira para unir engenharia\nde software + IA + estratégia de negócios, visando criar soluções\nque sejam ao mesmo tempo tecnicamente escaláveis e orientadas a\nresultados.\nExperiência\nAvanade\n5 anos 2 meses\nConsultor Sênior | Tech Architect\njunho de 2022\xa0-\xa0Present\xa0(3 anos 5 meses)\nNova Lima, Minas Gerais, Brazil\nConsultor Fullstack - Software Engineering\nsetembro de 2020\xa0-\xa0Present\xa0(5 anos 2 meses)\n\xa0 Page 1 of 3\xa0 \xa0\nBrazil\n• Referência técnica para um time com 15+ Software Engineers\n• Desenvolvimento de frameworks internos \n• Definição técnica de projetos\n• Melhoria na performance refatorando aplicações com código legado\nHTP Solution\nEngenheiro de software sênior\nmaio de 2018\xa0-\xa0setembro de 2020\xa0(2 anos 5 meses)\nBelo Horizonte, Minas Gerais\n• Desenvolvimento e manutenção de solução de monitoramento de veículos\ncom 4M+ de viagens rastreadas por dia\n• Padronização e evolução de aplicativos mobile com a plataforma Xamarin\n• Referência técnica em aplciações mobile\nPrológica Sistemas\nDesenvolvedor - Sócio\nfevereiro de 2012\xa0-\xa0abril de 2020\xa0(8 anos 3 meses)\nBelo Horizonte\n• Identificação de problemas e elaboração de projetos voltados à solução do\nnegócio\n• Desenvolvimento de sistemas para desktop e aplicações web\n• Prospecção de clientes e novas oportunidades\nPumalog\nAssistente de Informática\nabril de 2010\xa0-\xa0março de 2011\xa0(1 ano)\n• Desenvolvimento de soluções para geração de boletos bancári ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a bachelor's degree?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# "Yes, I hold a Bachelor's degree in Information Systems, which I completed at Pontifícia Universidade Católica de Minas Gerais between 2011 and 2014. If you have any more questions about my education or background, feel free to ask!"

# %%
evaluate(reply, "do you hold a bachelor's degree?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='This is a great response, providing a clear and concise answer to the question. It also adopts a friendly tone and invites further questions.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The response is in pig latin, which is not professional. The agent should respond in Portuguese, since the user is asking questions in Portuguese.
